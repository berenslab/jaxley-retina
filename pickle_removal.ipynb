# %%
import pickle
import numpy as np

# %%
# Params
with open("/home/kyra/Documents/Jaxley/neurips-code/jaxley-retina/params/cascade/params_0.pkl", "rb") as f:
    params = pickle.load(f)
params
# Out:
# [{'PR_Phototransduction_sigma': Array([12.605677], dtype=float32)},
#  {'PR_Phototransduction_phi': Array([12.444437], dtype=float32)},
#  {'PR_Phototransduction_eta': Array([768.30963], dtype=float32)},
#  {'PR_Phototransduction_gamma': Array([17.95673], dtype=float32)},
#  {'PR_Phototransduction_beta': Array([2.8434145], dtype=float32)},
#  {'PR_Phototransduction_k': Array([0.01194204], dtype=float32)},
#  {'PR_Phototransduction_m': Array([4.0815825], dtype=float32)},
#  {'PR_Phototransduction_n': Array([2.9429605], dtype=float32)},
#  {'PR_Phototransduction_K_GC': Array([0.34688187], dtype=float32)},
#  {'PR_Phototransduction_G_dark': Array([22.018845], dtype=float32)},
#  {'PR_Phototransduction_C_dark': Array([1.0488224], dtype=float32)}]
